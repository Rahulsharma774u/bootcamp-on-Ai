# %%
print("srm ist")
# Out:
# srm ist

# %% [markdown]
# a)create a list of random number and print all the even number in the list

# %%
number=[3,5,4,6,77,33,21,22,44,55,78,76,75,43,24,64]
for num in number:
  if num% 2 == 0:
   print(num)
# Out:
# 4
# 6
# 22
# 44
# 78
# 76
# 24
# 64

# %% [markdown]
# b) create s string and print it in reverse

# %%
text = "Hello World"
print("Original string:", text)
print("Reverse string:", text[::-1])
# Out:
# Original string: Hello World
# Reverse string: dlroW olleH
