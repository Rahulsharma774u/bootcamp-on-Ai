# %%
# !pip install wordcloud

# %%
# Import necessary libraries
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter

# Ensure necessary NLTK data is downloaded
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# Provided text
text = """
### My Hobby

My favorite hobby is **playing cricket**. Cricket is not only a sport for me, but also a great way to relax, stay active, and spend quality time with my friends.
I enjoy playing cricket whenever I get free time from my studies and other responsibilities. I usually play with my friends in the evening or on weekends.
Cricket helps me improve my physical fitness, concentration, coordination, and teamwork. While playing, I learn the importance of discipline, patience, and making quick decisions.
 I also enjoy watching professional cricket matches because I get to see different players, strategies, and techniques.
  My favorite part of cricket is batting because I enjoy hitting different types of shots and trying to score runs for my team.
  However, I also like bowling and fielding because every role is important for the success of a team.
   Cricket teaches me that winning is not everything; learning from mistakes and supporting teammates are equally important. When I lose a match,
    I try to understand what went wrong and improve my performance next time.
    Playing cricket also gives me an opportunity to interact with different people and build strong friendships.
     It keeps me away from excessive screen time and gives me a healthy break from studying.
      I believe hobbies are important because they make our lives more enjoyable and balanced.
      For me, cricket is a source of happiness, energy, and motivation.
      I hope to continue playing cricket in the future while maintaining a good balance between my studies and personal interests.

"""
print(text)
# Out:
# ### My Hobby
#
# My favorite hobby is **playing cricket**. Cricket is not only a sport for me, but also a great way to relax, stay active, and spend quality time with my friends.
# I enjoy playing cricket whenever I get free time from my studies and other responsibilities. I usually play with my friends in the evening or on weekends.
# Cricket helps me improve my physical fitness, concentration, coordination, and teamwork. While playing, I learn the importance of discipline, patience, and making quick decisions.
#  I also enjoy watching professional cricket matches because I get to see different players, strategies, and techniques.
#   My favorite part of cricket is batting because I enjoy hitting different types of shots and trying to score runs for my team.
#   However, I also like bowling and fielding because every role is important for the success of a team.
# ...

# %%
nltk.download('punkt_tab')
# Tokenization of words
words = word_tokenize(text.lower())  # Convert to lowercase for uniformity
print(words)
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# ...

# %%
# Remove stopwords
stop_words = set(stopwords.words('english'))
filtered_words = [word for word in words if word.isalpha() and word not in stop_words]
# The general syntax for a list comprehension is: [expression for item in iterable if condition]
print(filtered_words)
# Out:
# ['hobby', 'favorite', 'hobby', 'playing', 'cricket', 'cricket', 'sport', 'also', 'great', 'way', 'relax', 'stay', 'active', 'spend', 'quality', 'time', 'friends', 'enjoy', 'playing', 'cricket', 'whenever', 'get', 'free', 'time', 'studies', 'responsibilities', 'usually', 'play', 'friends', 'evening', 'weekends', 'cricket', 'helps', 'improve', 'physical', 'fitness', 'concentration', 'coordination', 'teamwork', 'playing', 'learn', 'importance', 'discipline', 'patience', 'making', 'quick', 'decisions', 'also', 'enjoy', 'watching', 'professional', 'cricket', 'matches', 'get', 'see', 'different', 'players', 'strategies', 'techniques', 'favorite', 'part', 'cricket', 'batting', 'enjoy', 'hitting', 'different', 'types', 'shots', 'trying', 'score', 'runs', 'team', 'however', 'also', 'like', 'bowling', 'fielding', 'every', 'role', 'important', 'success', 'team', 'cricket', 'teaches', 'winning', 'everything', 'learning', 'mistakes', 'supporting', 'teammates', 'equally', 'important', 'lose', 'mat
# ...

# %%
# Create a WordCloud
word_freq = Counter(filtered_words)
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_freq)

# %%
# Plotting the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # Hide axes
plt.show()

# %%
word_freq=Counter(filtered_words)
print(word_freq)
# Out:
# Counter({'cricket': 10, 'playing': 5, 'also': 4, 'time': 4, 'enjoy': 3, 'different': 3, 'important': 3, 'hobby': 2, 'favorite': 2, 'friends': 2, 'get': 2, 'studies': 2, 'improve': 2, 'team': 2, 'gives': 2, 'sport': 1, 'great': 1, 'way': 1, 'relax': 1, 'stay': 1, 'active': 1, 'spend': 1, 'quality': 1, 'whenever': 1, 'free': 1, 'responsibilities': 1, 'usually': 1, 'play': 1, 'evening': 1, 'weekends': 1, 'helps': 1, 'physical': 1, 'fitness': 1, 'concentration': 1, 'coordination': 1, 'teamwork': 1, 'learn': 1, 'importance': 1, 'discipline': 1, 'patience': 1, 'making': 1, 'quick': 1, 'decisions': 1, 'watching': 1, 'professional': 1, 'matches': 1, 'see': 1, 'players': 1, 'strategies': 1, 'techniques': 1, 'part': 1, 'batting': 1, 'hitting': 1, 'types': 1, 'shots': 1, 'trying': 1, 'score': 1, 'runs': 1, 'however': 1, 'like': 1, 'bowling': 1, 'fielding': 1, 'every': 1, 'role': 1, 'success': 1, 'teaches': 1, 'winning': 1, 'everything': 1, 'learning': 1, 'mistakes': 1, 'supporting': 1, 'teammat
# ...
